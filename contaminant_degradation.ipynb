# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# ## Introduction – degradation of a sorbing contaminant

# %% [markdown]
# To investigate the degradation of a chemical pollutant on contaminated soil, an experiment is conducted in a laboratory. 20 g of the contaminated soil are incubated with water. The concentration of the contaminant are monitored in the water over time.
#
# The contaminant sorbs to the soil – that is, some of it sticks to the soil particles or grains.
# The sorbed concentration $s$ equilibrates quickly with the concentration of the pollutant in the water $c$. The relationship between the two is non-linear:
#
# $$s = K c^n$$
#
# Therefore, the total mass of the contaminant in the system, $m$ is
#
# $$m = c V + K c^n m_{\mathrm{soil}}$$
#
# where $V$ is the water volume and $m_{\mathrm{soil}}$ the mass of the soil.
#
# In addition, the pollutant is degraded according to a first-order rate law with coefficient $k$.
# The mass balance for the pollutant therefore is:
#
# $$\frac{dm}{dt} = \frac{dc}{dt} V + K  n c^{n-1} \frac{dc}{dt} m_{\mathrm{soil}} = -V k c$$
#
# This can be rearranged into an ordinary differential equation (ODE) for the concentration in the water:
#
# $$\frac{dc}{dt} = -\frac{1}{R(c)} kc$$
#
# where $R(c) = 1 + \alpha nc^{n-1}$ is a concentration-dependent retardation factor and $\alpha = \frac{K m_{\mathrm{soil}}}{V}$.
# Note that the retardation factor makes the ODE non-linear!
# The Python functions below implement the right-hand-side of the ODE.
#
# In this assignment, you will numerically solve this ODE to simulate the concentration of the pollutant during the experiment. You will compare different numerical solution techniques, including the implicit Euler scheme.

# %%
def compute_retardation_factor(c, alpha, n):
    """
    Calculate the retardation factor based on the concentration, sorption coefficient, and exponent.

    Parameters:
    - c: concentration
    - alpha: sorption coefficient
    - n: exponent for the sorption isotherm

    Returns:
    - R: retardation factor
    """
    return 1 + alpha * n * c ** (n - 1)


def decay_model_with_sorption(t, c, k, n, alpha):
    """
    Defines the ODE for the decay model with sorption.

    Parameters:
    - t: time
    - c: concentration at time t
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - dc/dt: rate of change of concentration
    """
    return -k * c / compute_retardation_factor(c, alpha, n)

# %% [markdown]
# ## Part 1: Implicit Euler scheme and Newton-Raphson method
#
# > **Task 1.1:**
# > Formulate the numerical expression for the given ODE using the implicit Euler scheme, in which the new (unknown) concentration is $c_{i+1}$.

# %% [markdown]
# > **Task 1.2:**
# >
# > To solve the discretized Euler scheme for non-linear functions, we apply the Newton-Raphson method to find the root of a function $g(z)$. What is $z$ for the given ODE? Provide an expression for g(z).

# %% [markdown]
# In the Newton-Raphson iterations, we obtain the new point as follows:
#
# $$z_{j+1} = z_j - \frac{g(z_j)}{g^\prime(z_j)}$$
#
# Applied to our model, this looks like this:
#
# $$c_{i+1}^{j+1} = c_{i+1}^j - \frac{q(c_{i+1}^j)}{q^\prime(c_{i+1}^j)}$$
#
# where $i$ is the index for the time step and $j$ is the index for the Newton-Raphson iteration.
#
# > **Task 1.3:**
# >
# > Fill in the code templates below to implement Python functions that evaluate $g(z)$ and $g^\prime(z)$.
# >
# > Consider that $g^\prime(z) = q^\prime(c_{i+1}) = 1- \Delta t f^\prime(c_{i+1}, t_{i+1})$ and use the following derivative for the right-hand-side of the ODE:
# >
# > $$f^\prime(c_{i+1}, t_{i+1}) = -k \left[\frac{1}{R(c_{i+1})} - \frac{\alpha n (n-1) {c_{i+1}}^{n-1}}{(R(c_{i+1}))^2}\right]$$
# >
# > Tip: This expression is already provided in the code template below.

# %%
def evaluate_g(c_next, c_prev, t_next, dt, k, n, alpha):
    """Evaluate the function g of which to find the root in the Newton-Raphson iterations

    Parameters
    ----------
    c_next: concentration at time t_{i+1}
    c_prev: concentration at time t_i
    t_next: time t_{i+1}
    dt: time increment
    k, n,alpha: model parameters
    """
    return  c_next - c_prev + dt * ((1/(1 + alpha * n * (c_next**(n-1)))) * k * c_next)


def evaluate_g_prime(c_next, t_next, dt, k, n, alpha):
    "Evaluate the derivative of g"
    retardation_factor = compute_retardation_factor(c_next, alpha, n)
    f_prime = -k * (
        1 / retardation_factor
        - alpha * n * (n - 1) * c_next ** (n - 1) / retardation_factor**2
    )
    return  f_prime

# %% [markdown]
# > **Task 1.4**
# >
# > Fill in the code template below to implement the implicit Euler scheme with Newton-Raphson iterations for the model.

# %%
# Define model parameters
dist_coeff = (
    100  # distribution coefficient [L/kg] # TODO: check units due to the exponent
)
mass = 0.02  # mass of soil [kg]
volume = 0.1  # volume of water [L]
alpha = dist_coeff * mass / volume  # sorption coefficient
k = 0.5  # decay constant [1/day]
n = 0.5
c0 = 10.0  # initial concentration

# %%
# Set up initial condition and time vector
dt = 0.1
t_end = np.maximum(100, dt * 2)
times = np.arange(0, t_end, dt)  # in days
n_times = len(times)

# Define algorithm options
tolerance = 1e-3  # tolerance ϵ for the Newton-Raphson iterations
# maximum number of Newton-Raphson iterations (to prevent an infinite loop)
max_iter = 50

# %%
def solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance=1e-3, max_iter=50):
    """
    Solve the decay model with sorption using the implicit Euler method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient
    - tolerance: tolerance for Newton-Raphson iterations
    - max_iter: maximum number of Newton-Raphson iterations

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]
    t_previous = 0

    # Initialize the current state
    c_prev = c0
    c_next = c0
    
    # Iterate over times
    for i in range(len(times)):
        t_next = times[i]

        # Initialize Newton-Raphson iterations: start with the current value as a guess
        j = 0
        q = evaluate_g(c_next, c_prev, t_next, dt, k, n, alpha)
        q_prime = evaluate_g_prime(c_next, t_next, dt, k, n, alpha)
        iter_count = 0

        # Newton-Raphson iterations
        while iter_count < max_iter:
            c_update = c_next - (q / q_prime)
            q_update = evaluate_g(c_update, c_prev, t_next, dt, k, n, alpha)
            q_p_update = evaluate_g_prime(c_update, t_next, dt, k, n, alpha)
            if abs(q_update) < tolerance:
                c_next = c_update
                break
            c_next = c_update
            q = q_update
            q_prime = q_p_update
            iter_count += 1

        if iter_count >= max_iter:
            print(f'Warning: Newton did not converge at t={t_next} (iter={iter_count})')
        c_prev = c_next
        c.append(c_next)
        t_previous = t_next
        if c_next <= 20:
            break
        
    # Convert list of states to a numpy array
    c_array = np.array(c) 
    return c_array

# %%
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
# Out:
# Warning: Newton did not converge at t=0.1 (iter=50)
# Warning: Newton did not converge at t=0.2 (iter=50)
# Warning: Newton did not converge at t=0.30000000000000004 (iter=50)
# Warning: Newton did not converge at t=0.4 (iter=50)
# Warning: Newton did not converge at t=0.5 (iter=50)
# Warning: Newton did not converge at t=0.6 (iter=50)
# Warning: Newton did not converge at t=0.7 (iter=50)
# Warning: Newton did not converge at t=0.7999999999999999 (iter=50)
# Warning: Newton did not converge at t=0.8999999999999999 (iter=50)
# Warning: Newton did not converge at t=0.9999999999999999 (iter=50)
# Warning: Newton did not converge at t=1.0999999999999999 (iter=50)
# Warning: Newton did not converge at t=1.2 (iter=50)
# Warning: Newton did not converge at t=1.3 (iter=50)
# Warning: Newton did not converge at t=1.4000000000000001 (iter=50)
# Warning: Newton did not converge at t=1.5000000000000002 (iter=50)
# Warning: Newton did not converge at t=1.6000000000000003 (iter=50)
# Warning: Newton did not converge at t=1.7000000000000004 (iter=50)
# Warning: Newton did not converge at t=1.8000000000000005 (iter=50)
# Warning: Newton did not converge at t=1.9000000000000006 (iter=50)
# Warning: Newton did not converge at t=2.0000000000000004 (iter=50)
# Warning: Newton did not converge at t=2.1000000000000005 (iter=50)
# Warning: Newton did not converge at t=2.2000000000000006 (iter=50)
# Warning: Newton did not converge at t=2.3000000000000007 (iter=50)
# Warning: Newton did not converge at t=2.400000000000001 (iter=50)
# Warning: Newton did not converge at t=2.500000000000001 (iter=50)
# Warning: Newton did not converge at t=2.600000000000001 (iter=50)
# Warning: Newton did not converge at t=2.700000000000001 (iter=50)
# Warning: Newton did not converge at t=2.800000000000001 (iter=50)
# Warning: Newton did not converge at t=2.9000000000000012 (iter=50)
# Warning: Newton did not converge at t=3.0000000000000013 (iter=50)
# Warning: Newton did not converge at t=3.1000000000000014 (iter=50)
# Warning: Newton did not converge at t=3.2000000000000015 (iter=50)
# Warning: Newton did not converge at t=3.3000000000000016 (iter=50)
# Warning: Newton did not converge at t=3.4000000000000017 (iter=50)
# Warning: Newton did not converge at t=3.5000000000000018 (iter=50)
# Warning: Newton did not converge at t=3.600000000000002 (iter=50)
# Warning: Newton did not converge at t=3.700000000000002 (iter=50)
# Warning: Newton did not converge at t=3.800000000000002 (iter=50)
# Warning: Newton did not converge at t=3.900000000000002 (iter=50)
# Warning: Newton did not converge at t=4.000000000000002 (iter=50)
# Warning: Newton did not converge at t=4.100000000000001 (iter=50)
# Warning: Newton did not converge at t=4.200000000000001 (iter=50)
# Warning: Newton did not converge at t=4.300000000000001 (iter=50)
# Warning: Newton did not converge at t=4.4 (iter=50)
# Warning: Newton did not converge at t=4.5 (iter=50)
# Warning: Newton did not converge at t=4.6 (iter=50)
# Warning: Newton did not converge at t=95.89999999999883 (iter=50)
# Warning: Newton did not converge at t=95.99999999999882 (iter=50)
# Warning: Newton did not converge at t=96.09999999999881 (iter=50)
# Warning: Newton did not converge at t=96.19999999999881 (iter=50)
# Warning: Newton did not converge at t=96.2999999999988 (iter=50)
# Warning: Newton did not converge at t=96.3999999999988 (iter=50)
# Warning: Newton did not converge at t=96.49999999999879 (iter=50)
# Warning: Newton did not converge at t=96.59999999999879 (iter=50)
# Warning: Newton did not converge at t=96.69999999999878 (iter=50)
# Warning: Newton did not converge at t=96.79999999999878 (iter=50)
# Warning: Newton did not converge at t=96.89999999999877 (iter=50)
# Warning: Newton did not converge at t=96.99999999999876 (iter=50)
# Warning: Newton did not converge at t=97.09999999999876 (iter=50)
# Warning: Newton did not converge at t=97.19999999999875 (iter=50)
# Warning: Newton did not converge at t=97.29999999999875 (iter=50)
# Warning: Newton did not converge at t=97.39999999999874 (iter=50)
# Warning: Newton did not converge at t=97.49999999999874 (iter=50)
# Warning: Newton did not converge at t=97.59999999999873 (iter=50)
# Warning: Newton did not converge at t=97.69999999999872 (iter=50)
# Warning: Newton did not converge at t=97.79999999999872 (iter=50)
# Warning: Newton did not converge at t=97.89999999999871 (iter=50)
# Warning: Newton did not converge at t=97.9999999999987 (iter=50)
# Warning: Newton did not converge at t=98.0999999999987 (iter=50)
# Warning: Newton did not converge at t=98.1999999999987 (iter=50)
# Warning: Newton did not converge at t=98.29999999999869 (iter=50)
# Warning: Newton did not converge at t=98.39999999999868 (iter=50)
# Warning: Newton did not converge at t=98.49999999999868 (iter=50)
# Warning: Newton did not converge at t=98.59999999999867 (iter=50)
# Warning: Newton did not converge at t=98.69999999999867 (iter=50)
# Warning: Newton did not converge at t=98.79999999999866 (iter=50)
# Warning: Newton did not converge at t=98.89999999999866 (iter=50)
# Warning: Newton did not converge at t=98.99999999999865 (iter=50)
# Warning: Newton did not converge at t=99.09999999999864 (iter=50)
# Warning: Newton did not converge at t=99.19999999999864 (iter=50)
# Warning: Newton did not converge at t=99.29999999999863 (iter=50)
# Warning: Newton did not converge at t=99.39999999999863 (iter=50)
# Warning: Newton did not converge at t=99.49999999999862 (iter=50)
# Warning: Newton did not converge at t=99.59999999999862 (iter=50)
# Warning: Newton did not converge at t=99.69999999999861 (iter=50)
# Warning: Newton did not converge at t=99.7999999999986 (iter=50)
# Warning: Newton did not converge at t=99.8999999999986 (iter=50)
# Warning: Newton did not converge at t=99.9999999999986 (iter=50)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
#
# Cell In[59], line 29, in solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
#      25     c_next = c0
#      26
#      27     # Iterate over times
#      28     for i in range(len(times) + 1):
# ---> 29         t_next = times[i]
#      30
#      31         # Initialize Newton-Raphson iterations: start with the current value as a guess
#      32         j = 0
#
# IndexError: index 1000 is out of bounds for axis 0 with size 1000

# %% [markdown]
# > **Task 1.5**
# >
# > Compare your solution to the reference solution below. The reference solution is created by running an accurate solver from the Scipy library. You can use it to evaluate your implementation. If you choose a small time step (0.1 days), and your implementation is correct, the solutions should look the same.

# %%
# Compute reference solution using scipy's solve_ivp
t_end = times[-1]
t_dense = np.linspace(0, t_end, 6000)
sol = solve_ivp(
    decay_model_with_sorption,
    t_span=(0, t_end),
    y0=np.array([c0]),
    t_eval=t_dense,
    args=(k, n, alpha),
    max_step=0.8,
    method="BDF",
)

# %%
# Plot the implicit Euler solution against the reference solution
plt.plot(times, c_implicit, label="implicit Euler")
plt.plot(sol.t, sol.y[0], label="scipy solution")
plt.legend()
plt.xlabel("time")
plt.ylabel("$C$ [mol/L]")
plt.ylim(bottom=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 # Plot the implicit Euler solution against the reference solution
# ----> 2 plt.plot(times, c_implicit, label="implicit Euler")
#       3 plt.plot(sol.t, sol.y[0], label="scipy solution")
#       4 plt.legend()
#       5 plt.xlabel("time")
#
# File ~\tudelft-conda\envs\mude-base-2026\Lib\site-packages\matplotlib\pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
#    4045         scalex=scalex,
#    4046         scaley=scaley,
#    4047         **({"data": data} if data is not None else {}),
#    4048         **kwargs,
#    4049     )
#
# File ~\tudelft-conda\envs\mude-base-2026\Lib\site-packages\matplotlib\axes\_axes.py:1792, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1549 """
#    1550 Plot y versus x as lines and/or markers.
#    1551
#    (...)   1789 (``'green'``) or hex strings (``'#008000'``).
#    1790 """
#    1791 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1792 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1793 for line in lines:
#    1794     self.add_line(line)
#
# File ~\tudelft-conda\envs\mude-base-2026\Lib\site-packages\matplotlib\axes\_base.py:331, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     329     this += args[0],
#     330     args = args[1:]
# --> 331 yield from self._plot_args(
#     332     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     333     return_kwargs=return_kwargs
#     334 )
#
# File ~\tudelft-conda\envs\mude-base-2026\Lib\site-packages\matplotlib\axes\_base.py:509, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     506     axes.yaxis.update_units(y)
#     508 if x.shape[0] != y.shape[0]:
# --> 509     raise ValueError(f"x and y must have same first dimension, but "
#     510                      f"have shapes {x.shape} and {y.shape}")
#     511 if x.ndim > 2 or y.ndim > 2:
#     512     raise ValueError(f"x and y can be no greater than 2D, but have "
#     513                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1000,) and (1001,)

# %% [markdown]
# ## Part 2: Adams-Bashfort method
#
#
# > **Task 2.1**
# >
# > Fill in the code template below to implement a solution of the decay model with the Adams-Bashforth method.

# %%
def solve_adams_bashforth(c0, times, dt, k, n, alpha):
    """
    Solve the decay model with sorption using the Adams-Bashforth method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]

    # Initialize the current state
    c_i = c0

    # Iterate over times
    for i in range(len(times) - 1):
        t_i = times[i]
        
        ### YOUR CODE LINES HERE

    # Convert list of states to a numpy array
    c_array = np.array(c)
    return c_array

# %% [markdown]
# ## Part 3: Numerical stability and accuracy
#
# The code below compares the solution obtained with the implicit Euler scheme to the solution from the explicit Euler scheme and the reference solution.

# %%
def solve_explicit_euler(c0, times, dt, k, n, alpha):
    """
    Solve the decay model with sorption using the explicit Euler method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]

    # Initialize the current state
    c_prev = c0

    # Iterate over times
    for i in range(1, len(times)):
        t_next = times[i]
        # Explicit Euler update
        c_next = c_prev + dt * decay_model_with_sorption(t_next, c_prev, k, n, alpha)
        c.append(c_next)
        c_prev = c_next

    # Convert list of states to a numpy array
    c_array = np.array(c)
    return c_array

# %% [markdown]
# > **Task 3.1**
# >
# > Run the code cell below that plots the solution obtained with the Adams-Bashforth method to the solution from the implicit and explicit Euler scheme (using the same time step size of $\Delta t = 2 \,\mathrm{d}$). Compare the accuracy of the Adams-Bashforth solution to the one from the Euler schemes.

# %%
dt = 2
t_end = np.maximum(100, dt * 5)
times = np.arange(0, t_end + dt, dt)  # in days
n_times = len(times)

c_adams_bashforth = solve_adams_bashforth(c0, times, dt=dt, k=k, n=n, alpha=alpha)
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
c_explicit = solve_explicit_euler(c0, times, dt, k, n, alpha)
plt.plot(sol.t, sol.y[0], label="reference solution", color="black")
plt.plot(times, c_adams_bashforth, label="Adams-Bashforth")
plt.plot(times, c_implicit, label="Implicit Euler")
plt.plot(times, c_explicit, label="Explicit Euler")
plt.legend()

# %% [markdown]
# > **Task 3.2**
# >
# > Vary the time step in the code cell below, using values of 0.1 day, 5 day, 10 days, 15 days. Compare the behavior of the implicit and explicit Euler scheme and the Adams-Bashforth scheme at the different time step sizes.
# >
# > Take notes about the results – you will need them for the report later on. You may also want to schematically sketch the plots (exact values are not important).

# %%
dt = 0.1
t_end = np.maximum(100, dt * 5)
times = np.arange(0, t_end + dt, dt)  # in days
n_times = len(times)

c_adams_bashforth = solve_adams_bashforth(c0, times, dt=dt, k=k, n=n, alpha=alpha)
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
c_explicit = solve_explicit_euler(c0, times, dt, k, n, alpha)
plt.plot(sol.t, sol.y[0], label="reference solution", color="black")
plt.plot(times, c_adams_bashforth, label="Adams-Bashforth")
plt.plot(times, c_implicit, label="Implicit Euler")
plt.plot(times, c_explicit, label="Explicit Euler")
plt.legend()
plt.title(fr"Solution for $\Delta t = {dt} \,\mathrm{{d}}$")

# %% [markdown]
# > By Anna Störiko and Ronald Brinkgreve, Delft University of Technology. CC BY 4.0, more info [on the Credits page of Workbook](https://mude.citg.tudelft.nl/workbook-2026/credits.html).
