# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# ## Introduction – degradation of a sorbing contaminant

# %% [markdown]
# To investigate the degradation of a chemical pollutant on contaminated soil, an experiment is conducted in a laboratory. 20 g of the contaminated soil are incubated with water. The concentration of the contaminant are monitored in the water over time.
#
# The contaminant sorbs to the soil – that is, some of it sticks to the soil particles or grains.
# The sorbed concentration $s$ equilibrates quickly with the concentration of the pollutant in the water $c$. The relationship between the two is non-linear:
#
# $$s = K c^n$$
#
# Therefore, the total mass of the contaminant in the system, $m$ is
#
# $$m = c V + K c^n m_{\mathrm{soil}}$$
#
# where $V$ is the water volume and $m_{\mathrm{soil}}$ the mass of the soil.
#
# In addition, the pollutant is degraded according to a first-order rate law with coefficient $k$.
# The mass balance for the pollutant therefore is:
#
# $$\frac{dm}{dt} = \frac{dc}{dt} V + K  n c^{n-1} \frac{dc}{dt} m_{\mathrm{soil}} = -V k c$$
#
# This can be rearranged into an ordinary differential equation (ODE) for the concentration in the water:
#
# $$\frac{dc}{dt} = -\frac{1}{R(c)} kc$$
#
# where $R(c) = 1 + \alpha nc^{n-1}$ is a concentration-dependent retardation factor and $\alpha = \frac{K m_{\mathrm{soil}}}{V}$.
# Note that the retardation factor makes the ODE non-linear!
# The Python functions below implement the right-hand-side of the ODE.
#
# In this assignment, you will numerically solve this ODE to simulate the concentration of the pollutant during the experiment. You will compare different numerical solution techniques, including the implicit Euler scheme.

# %%
def compute_retardation_factor(c, alpha, n):
    """
    Calculate the retardation factor based on the concentration, sorption coefficient, and exponent.

    Parameters:
    - c: concentration
    - alpha: sorption coefficient
    - n: exponent for the sorption isotherm

    Returns:
    - R: retardation factor
    """
    return 1 + alpha * n * c ** (n - 1)


def decay_model_with_sorption(t, c, k, n, alpha):
    """
    Defines the ODE for the decay model with sorption.

    Parameters:
    - t: time
    - c: concentration at time t
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - dc/dt: rate of change of concentration
    """
    return -k * c / compute_retardation_factor(c, alpha, n)

# %% [markdown]
# ## Part 1: Implicit Euler scheme and Newton-Raphson method
#
# > **Task 1.1:**
# > Formulate the numerical expression for the given ODE using the implicit Euler scheme, in which the new (unknown) concentration is $c_{i+1}$.

# %% [markdown]
# > **Task 1.2:**
# >
# > To solve the discretized Euler scheme for non-linear functions, we apply the Newton-Raphson method to find the root of a function $g(z)$. What is $z$ for the given ODE? Provide an expression for g(z).

# %% [markdown]
# In the Newton-Raphson iterations, we obtain the new point as follows:
#
# $$z_{j+1} = z_j - \frac{g(z_j)}{g^\prime(z_j)}$$
#
# Applied to our model, this looks like this:
#
# $$c_{i+1}^{j+1} = c_{i+1}^j - \frac{q(c_{i+1}^j)}{q^\prime(c_{i+1}^j)}$$
#
# where $i$ is the index for the time step and $j$ is the index for the Newton-Raphson iteration.
#
# > **Task 1.3:**
# >
# > Fill in the code templates below to implement Python functions that evaluate $g(z)$ and $g^\prime(z)$.
# >
# > Consider that $g^\prime(z) = q^\prime(c_{i+1}) = 1- \Delta t f^\prime(c_{i+1}, t_{i+1})$ and use the following derivative for the right-hand-side of the ODE:
# >
# > $$f^\prime(c_{i+1}, t_{i+1}) = -k \left[\frac{1}{R(c_{i+1})} - \frac{\alpha n (n-1) {c_{i+1}}^{n-1}}{(R(c_{i+1}))^2}\right]$$
# >
# > Tip: This expression is already provided in the code template below.

# %%
def evaluate_g(c_next, c_prev, t_next, dt, k, n, alpha):
    """Evaluate the function g of which to find the root in the Newton-Raphson iterations

    Parameters
    ----------
    c_next: concentration at time t_{i+1}
    c_prev: concentration at time t_i
    t_next: time t_{i+1}
    dt: time increment
    k, n,alpha: model parameters
    """
    return  c_next - c_prev + dt * k * c_next / compute_retardation_factor(c_next, alpha, n)
    
    # c_prev + dt * 1/compute_retardation_factor(c_next, alpha, n) * c_next * k - c_next


def evaluate_g_prime(c_next, t_next, dt, k, n, alpha):
    "Evaluate the derivative of g"
    retardation_factor = compute_retardation_factor(c_next, alpha, n)
    f_prime = -k * (
        1 / retardation_factor
        - alpha * n * (n - 1) * c_next ** (n - 1) / retardation_factor**2
    )
    return 1 - dt * f_prime

# %% [markdown]
# > **Task 1.4**
# >
# > Fill in the code template below to implement the implicit Euler scheme with Newton-Raphson iterations for the model.

# %%
# Define model parameters
dist_coeff = (
    100  # distribution coefficient [L/kg] # TODO: check units due to the exponent
)
mass = 0.02  # mass of soil [kg]
volume = 0.1  # volume of water [L]
alpha = dist_coeff * mass / volume  # sorption coefficient
k = 0.5  # decay constant [1/day]
n = 0.5
c0 = 10.0  # initial concentration

# %%
# Set up initial condition and time vector
dt = 0.1
t_end = np.maximum(100, dt * 2)
times = np.arange(0, t_end, dt)  # in days
n_times = len(times)

# Define algorithm options
tolerance = 1e-3  # tolerance ϵ for the Newton-Raphson iterations
# maximum number of Newton-Raphson iterations (to prevent an infinite loop)
max_iter = 50

# %%
def solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance=1e-3, max_iter=50):
    """
    Solve the decay model with sorption using the implicit Euler method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient
    - tolerance: tolerance for Newton-Raphson iterations
    - max_iter: maximum number of Newton-Raphson iterations

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]

    # Initialize the current state
    c_prev = c0

    # Iterate over times
    for i in range(1,n_times):
        t_next = times[i]


        # Initialize Newton-Raphson iterations: start with the current value as a guess
        j = 0
        c_next = c_prev

        # Compute g and g_prime once for the current guess c_next
        g = evaluate_g(c_next, c_prev, t_next, dt, k, n, alpha)
        g_prime = evaluate_g_prime(c_next, t_next, dt, k, n, alpha)
        c_update = c_next - g/g_prime


        # Newton-Raphson iterations
        while j < max_iter :
            
            # Update the guess using Newton-Raphson formula
            g_update = evaluate_g(c_update, c_prev, t_next, dt, k, n, alpha)
            g_prime_update = evaluate_g_prime(c_update, t_next, dt, k, n, alpha)
            c_update = c_next - g_update / g_prime_update 

            # Check for convergence
            if abs(c_update) < tolerance:
                c_next = c_update
                break


            # Promote the updated values for the next iteration (avoid recomputing g)
            c_next = c_update
            g = g_update
            g_prime = g_prime_update
            j += 1

        if j >= max_iter:
            print(f"Warning: Newton did not converge at t={t_next} (i={j})")

        # Update the values for the next time step using the converged r_next
        c_prev = c_next
        c.append(c_next)
        
    # Convert list of states to a numpy array
    c_array = np.array(c)
    return c_array

# %%
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
# Out:
# Warning: Newton did not converge at t=0.1 (i=50)
# Warning: Newton did not converge at t=0.2 (i=50)
# Warning: Newton did not converge at t=0.30000000000000004 (i=50)
# Warning: Newton did not converge at t=0.4 (i=50)
# Warning: Newton did not converge at t=0.5 (i=50)
# Warning: Newton did not converge at t=0.6000000000000001 (i=50)
# Warning: Newton did not converge at t=0.7000000000000001 (i=50)
# Warning: Newton did not converge at t=0.8 (i=50)
# Warning: Newton did not converge at t=0.9 (i=50)
# Warning: Newton did not converge at t=1.0 (i=50)
# Warning: Newton did not converge at t=1.1 (i=50)
# Warning: Newton did not converge at t=1.2000000000000002 (i=50)
# Warning: Newton did not converge at t=1.3 (i=50)
# Warning: Newton did not converge at t=1.4000000000000001 (i=50)
# Warning: Newton did not converge at t=1.5 (i=50)
# Warning: Newton did not converge at t=1.6 (i=50)
# Warning: Newton did not converge at t=1.7000000000000002 (i=50)
# Warning: Newton did not converge at t=1.8 (i=50)
# Warning: Newton did not converge at t=1.9000000000000001 (i=50)
# Warning: Newton did not converge at t=2.0 (i=50)
# Warning: Newton did not converge at t=2.1 (i=50)
# Warning: Newton did not converge at t=2.2 (i=50)
# Warning: Newton did not converge at t=2.3000000000000003 (i=50)
# Warning: Newton did not converge at t=2.4000000000000004 (i=50)
# Warning: Newton did not converge at t=2.5 (i=50)
# Warning: Newton did not converge at t=2.6 (i=50)
# Warning: Newton did not converge at t=2.7 (i=50)
# Warning: Newton did not converge at t=2.8000000000000003 (i=50)
# Warning: Newton did not converge at t=2.9000000000000004 (i=50)
# Warning: Newton did not converge at t=3.0 (i=50)
# Warning: Newton did not converge at t=3.1 (i=50)
# Warning: Newton did not converge at t=3.2 (i=50)
# Warning: Newton did not converge at t=3.3000000000000003 (i=50)
# Warning: Newton did not converge at t=3.4000000000000004 (i=50)
# Warning: Newton did not converge at t=3.5 (i=50)
# Warning: Newton did not converge at t=3.6 (i=50)
# Warning: Newton did not converge at t=3.7 (i=50)
# Warning: Newton did not converge at t=3.8000000000000003 (i=50)
# Warning: Newton did not converge at t=3.9000000000000004 (i=50)
# Warning: Newton did not converge at t=4.0 (i=50)
# Warning: Newton did not converge at t=4.1000000000000005 (i=50)
# Warning: Newton did not converge at t=4.2 (i=50)
# Warning: Newton did not converge at t=4.3 (i=50)
# Warning: Newton did not converge at t=4.4 (i=50)
# Warning: Newton did not converge at t=4.5 (i=50)
# Warning: Newton did not converge at t=4.6000000000000005 (i=50)
# Warning: Newton did not converge at t=4.7 (i=50)
# Warning: Newton did not converge at t=4.800000000000001 (i=50)
# Warning: Newton did not converge at t=4.9 (i=50)
# Warning: Newton did not converge at t=5.0 (i=50)
# Warning: Newton did not converge at t=5.1000000000000005 (i=50)
# Warning: Newton did not converge at t=5.2 (i=50)
# Warning: Newton did not converge at t=5.300000000000001 (i=50)
# Warning: Newton did not converge at t=5.4 (i=50)
# Warning: Newton did not converge at t=5.5 (i=50)
# Warning: Newton did not converge at t=5.6000000000000005 (i=50)
# Warning: Newton did not converge at t=5.7 (i=50)
# Warning: Newton did not converge at t=5.800000000000001 (i=50)
# Warning: Newton did not converge at t=5.9 (i=50)
# Warning: Newton did not converge at t=6.0 (i=50)
# Warning: Newton did not converge at t=6.1000000000000005 (i=50)
# Warning: Newton did not converge at t=6.2 (i=50)
# Warning: Newton did not converge at t=6.300000000000001 (i=50)
# Warning: Newton did not converge at t=6.4 (i=50)
# Warning: Newton did not converge at t=6.5 (i=50)
# Warning: Newton did not converge at t=6.6000000000000005 (i=50)
# Warning: Newton did not converge at t=6.7 (i=50)
# Warning: Newton did not converge at t=6.800000000000001 (i=50)
# Warning: Newton did not converge at t=6.9 (i=50)
# Warning: Newton did not converge at t=7.0 (i=50)
# Warning: Newton did not converge at t=7.1000000000000005 (i=50)
# Warning: Newton did not converge at t=7.2 (i=50)
# Warning: Newton did not converge at t=7.300000000000001 (i=50)
# Warning: Newton did not converge at t=7.4 (i=50)
# Warning: Newton did not converge at t=7.5 (i=50)
# Warning: Newton did not converge at t=7.6000000000000005 (i=50)
# Warning: Newton did not converge at t=7.7 (i=50)
# Warning: Newton did not converge at t=7.800000000000001 (i=50)
# Warning: Newton did not converge at t=7.9 (i=50)
# Warning: Newton did not converge at t=8.0 (i=50)
# Warning: Newton did not converge at t=8.1 (i=50)
# Warning: Newton did not converge at t=8.200000000000001 (i=50)
# Warning: Newton did not converge at t=8.3 (i=50)
# Warning: Newton did not converge at t=8.4 (i=50)
# Warning: Newton did not converge at t=8.5 (i=50)
# Warning: Newton did not converge at t=8.6 (i=50)
# Warning: Newton did not converge at t=8.700000000000001 (i=50)
# Warning: Newton did not converge at t=8.8 (i=50)
# Warning: Newton did not converge at t=8.9 (i=50)
# Warning: Newton did not converge at t=9.0 (i=50)
# Warning: Newton did not converge at t=9.1 (i=50)
# Warning: Newton did not converge at t=9.200000000000001 (i=50)
# Warning: Newton did not converge at t=9.3 (i=50)
# Warning: Newton did not converge at t=9.4 (i=50)
# Warning: Newton did not converge at t=9.5 (i=50)
# Warning: Newton did not converge at t=9.600000000000001 (i=50)
# Warning: Newton did not converge at t=9.700000000000001 (i=50)
# Warning: Newton did not converge at t=9.8 (i=50)
# Warning: Newton did not converge at t=9.9 (i=50)
# Warning: Newton did not converge at t=10.0 (i=50)
# Warning: Newton did not converge at t=10.100000000000001 (i=50)
# Warning: Newton did not converge at t=10.200000000000001 (i=50)
# Warning: Newton did not converge at t=10.3 (i=50)
# Warning: Newton did not converge at t=10.4 (i=50)
# Warning: Newton did not converge at t=10.5 (i=50)
# Warning: Newton did not converge at t=10.600000000000001 (i=50)
# Warning: Newton did not converge at t=10.700000000000001 (i=50)
# Warning: Newton did not converge at t=10.8 (i=50)
# Warning: Newton did not converge at t=10.9 (i=50)
# Warning: Newton did not converge at t=11.0 (i=50)
# Warning: Newton did not converge at t=11.100000000000001 (i=50)
# Warning: Newton did not converge at t=11.200000000000001 (i=50)
# Warning: Newton did not converge at t=11.3 (i=50)
# Warning: Newton did not converge at t=11.4 (i=50)
# Warning: Newton did not converge at t=11.5 (i=50)
# Warning: Newton did not converge at t=11.600000000000001 (i=50)
# Warning: Newton did not converge at t=11.700000000000001 (i=50)
# Warning: Newton did not converge at t=11.8 (i=50)
# Warning: Newton did not converge at t=11.9 (i=50)
# Warning: Newton did not converge at t=12.0 (i=50)
# Warning: Newton did not converge at t=12.100000000000001 (i=50)
# Warning: Newton did not converge at t=12.200000000000001 (i=50)
# Warning: Newton did not converge at t=12.3 (i=50)
# Warning: Newton did not converge at t=12.4 (i=50)
# Warning: Newton did not converge at t=12.5 (i=50)
# Warning: Newton did not converge at t=12.600000000000001 (i=50)
# Warning: Newton did not converge at t=12.700000000000001 (i=50)
# Warning: Newton did not converge at t=12.8 (i=50)
# Warning: Newton did not converge at t=12.9 (i=50)
# Warning: Newton did not converge at t=13.0 (i=50)
# Warning: Newton did not converge at t=13.100000000000001 (i=50)
# Warning: Newton did not converge at t=13.200000000000001 (i=50)
# Warning: Newton did not converge at t=13.3 (i=50)
# Warning: Newton did not converge at t=13.4 (i=50)
# Warning: Newton did not converge at t=13.5 (i=50)
# Warning: Newton did not converge at t=13.600000000000001 (i=50)
# Warning: Newton did not converge at t=13.700000000000001 (i=50)
# Warning: Newton did not converge at t=13.8 (i=50)
# Warning: Newton did not converge at t=13.9 (i=50)
# Warning: Newton did not converge at t=14.0 (i=50)
# Warning: Newton did not converge at t=14.100000000000001 (i=50)
# Warning: Newton did not converge at t=14.200000000000001 (i=50)
# Warning: Newton did not converge at t=14.3 (i=50)
# Warning: Newton did not converge at t=14.4 (i=50)
# Warning: Newton did not converge at t=14.5 (i=50)
# Warning: Newton did not converge at t=14.600000000000001 (i=50)
# Warning: Newton did not converge at t=14.700000000000001 (i=50)
# Warning: Newton did not converge at t=14.8 (i=50)
# Warning: Newton did not converge at t=14.9 (i=50)
# Warning: Newton did not converge at t=15.0 (i=50)
# Warning: Newton did not converge at t=15.100000000000001 (i=50)
# Warning: Newton did not converge at t=15.200000000000001 (i=50)
# Warning: Newton did not converge at t=15.3 (i=50)
# Warning: Newton did not converge at t=15.4 (i=50)
# Warning: Newton did not converge at t=15.5 (i=50)
# Warning: Newton did not converge at t=15.600000000000001 (i=50)
# Warning: Newton did not converge at t=15.700000000000001 (i=50)
# Warning: Newton did not converge at t=15.8 (i=50)
# Warning: Newton did not converge at t=15.9 (i=50)
# Warning: Newton did not converge at t=16.0 (i=50)
# Warning: Newton did not converge at t=16.1 (i=50)
# Warning: Newton did not converge at t=16.2 (i=50)
# Warning: Newton did not converge at t=16.3 (i=50)
# Warning: Newton did not converge at t=16.400000000000002 (i=50)
# Warning: Newton did not converge at t=16.5 (i=50)
# Warning: Newton did not converge at t=16.6 (i=50)
# Warning: Newton did not converge at t=16.7 (i=50)
# Warning: Newton did not converge at t=16.8 (i=50)
# Warning: Newton did not converge at t=16.900000000000002 (i=50)
# Warning: Newton did not converge at t=17.0 (i=50)
# Warning: Newton did not converge at t=17.1 (i=50)
# Warning: Newton did not converge at t=17.2 (i=50)
# Warning: Newton did not converge at t=17.3 (i=50)
# Warning: Newton did not converge at t=17.400000000000002 (i=50)
# Warning: Newton did not converge at t=17.5 (i=50)
# Warning: Newton did not converge at t=17.6 (i=50)
# Warning: Newton did not converge at t=17.7 (i=50)
# Warning: Newton did not converge at t=17.8 (i=50)
# Warning: Newton did not converge at t=17.900000000000002 (i=50)
# Warning: Newton did not converge at t=18.0 (i=50)
# Warning: Newton did not converge at t=18.1 (i=50)
# Warning: Newton did not converge at t=18.2 (i=50)
# Warning: Newton did not converge at t=18.3 (i=50)
# Warning: Newton did not converge at t=18.400000000000002 (i=50)
# Warning: Newton did not converge at t=18.5 (i=50)
# Warning: Newton did not converge at t=18.6 (i=50)
# Warning: Newton did not converge at t=18.7 (i=50)
# Warning: Newton did not converge at t=18.8 (i=50)
# Warning: Newton did not converge at t=18.900000000000002 (i=50)
# Warning: Newton did not converge at t=19.0 (i=50)
# Warning: Newton did not converge at t=19.1 (i=50)
# Warning: Newton did not converge at t=19.200000000000003 (i=50)
# Warning: Newton did not converge at t=19.3 (i=50)
# Warning: Newton did not converge at t=19.400000000000002 (i=50)
# Warning: Newton did not converge at t=19.5 (i=50)
# Warning: Newton did not converge at t=19.6 (i=50)
# Warning: Newton did not converge at t=19.700000000000003 (i=50)
# Warning: Newton did not converge at t=19.8 (i=50)
# Warning: Newton did not converge at t=19.900000000000002 (i=50)
# Warning: Newton did not converge at t=20.0 (i=50)
# Warning: Newton did not converge at t=20.1 (i=50)
# Warning: Newton did not converge at t=20.200000000000003 (i=50)
# Warning: Newton did not converge at t=20.3 (i=50)
# Warning: Newton did not converge at t=20.400000000000002 (i=50)
# Warning: Newton did not converge at t=20.5 (i=50)
# Warning: Newton did not converge at t=20.6 (i=50)
# Warning: Newton did not converge at t=20.700000000000003 (i=50)
# Warning: Newton did not converge at t=20.8 (i=50)
# Warning: Newton did not converge at t=20.900000000000002 (i=50)
# Warning: Newton did not converge at t=21.0 (i=50)
# Warning: Newton did not converge at t=21.1 (i=50)
# Warning: Newton did not converge at t=21.200000000000003 (i=50)
# Warning: Newton did not converge at t=21.3 (i=50)
# Warning: Newton did not converge at t=21.400000000000002 (i=50)
# Warning: Newton did not converge at t=21.5 (i=50)
# Warning: Newton did not converge at t=21.6 (i=50)
# Warning: Newton did not converge at t=21.700000000000003 (i=50)
# Warning: Newton did not converge at t=21.8 (i=50)
# Warning: Newton did not converge at t=21.900000000000002 (i=50)
# Warning: Newton did not converge at t=22.0 (i=50)
# Warning: Newton did not converge at t=22.1 (i=50)
# Warning: Newton did not converge at t=22.200000000000003 (i=50)
# Warning: Newton did not converge at t=22.3 (i=50)
# Warning: Newton did not converge at t=22.400000000000002 (i=50)
# Warning: Newton did not converge at t=22.5 (i=50)
# Warning: Newton did not converge at t=22.6 (i=50)
# Warning: Newton did not converge at t=22.700000000000003 (i=50)
# Warning: Newton did not converge at t=22.8 (i=50)
# Warning: Newton did not converge at t=22.900000000000002 (i=50)
# Warning: Newton did not converge at t=23.0 (i=50)
# Warning: Newton did not converge at t=23.1 (i=50)
# Warning: Newton did not converge at t=23.200000000000003 (i=50)
# Warning: Newton did not converge at t=23.3 (i=50)
# Warning: Newton did not converge at t=23.400000000000002 (i=50)
# Warning: Newton did not converge at t=23.5 (i=50)
# Warning: Newton did not converge at t=23.6 (i=50)
# Warning: Newton did not converge at t=23.700000000000003 (i=50)
# Warning: Newton did not converge at t=23.8 (i=50)
# Warning: Newton did not converge at t=23.900000000000002 (i=50)
# Warning: Newton did not converge at t=24.0 (i=50)
# Warning: Newton did not converge at t=24.1 (i=50)
# Warning: Newton did not converge at t=24.200000000000003 (i=50)
# Warning: Newton did not converge at t=24.3 (i=50)
# Warning: Newton did not converge at t=24.400000000000002 (i=50)
# Warning: Newton did not converge at t=24.5 (i=50)
# Warning: Newton did not converge at t=24.6 (i=50)
# Warning: Newton did not converge at t=24.700000000000003 (i=50)
# Warning: Newton did not converge at t=24.8 (i=50)
# Warning: Newton did not converge at t=24.900000000000002 (i=50)
# Warning: Newton did not converge at t=25.0 (i=50)
# Warning: Newton did not converge at t=25.1 (i=50)
# Warning: Newton did not converge at t=25.200000000000003 (i=50)
# Warning: Newton did not converge at t=25.3 (i=50)
# Warning: Newton did not converge at t=25.400000000000002 (i=50)
# Warning: Newton did not converge at t=25.5 (i=50)
# Warning: Newton did not converge at t=25.6 (i=50)
# Warning: Newton did not converge at t=25.700000000000003 (i=50)
# Warning: Newton did not converge at t=25.8 (i=50)
# Warning: Newton did not converge at t=25.900000000000002 (i=50)
# Warning: Newton did not converge at t=26.0 (i=50)
# Warning: Newton did not converge at t=26.1 (i=50)
# Warning: Newton did not converge at t=26.200000000000003 (i=50)
# Warning: Newton did not converge at t=26.3 (i=50)
# Warning: Newton did not converge at t=26.400000000000002 (i=50)
# Warning: Newton did not converge at t=26.5 (i=50)
# Warning: Newton did not converge at t=26.6 (i=50)
# Warning: Newton did not converge at t=26.700000000000003 (i=50)
# Warning: Newton did not converge at t=26.8 (i=50)
# Warning: Newton did not converge at t=26.900000000000002 (i=50)
# Warning: Newton did not converge at t=27.0 (i=50)
# Warning: Newton did not converge at t=27.1 (i=50)
# Warning: Newton did not converge at t=27.200000000000003 (i=50)
# Warning: Newton did not converge at t=27.3 (i=50)
# Warning: Newton did not converge at t=27.400000000000002 (i=50)
# Warning: Newton did not converge at t=27.5 (i=50)
# Warning: Newton did not converge at t=27.6 (i=50)
# Warning: Newton did not converge at t=27.700000000000003 (i=50)
# Warning: Newton did not converge at t=27.8 (i=50)
# Warning: Newton did not converge at t=27.900000000000002 (i=50)
# Warning: Newton did not converge at t=28.0 (i=50)
# Warning: Newton did not converge at t=28.1 (i=50)
# Warning: Newton did not converge at t=28.200000000000003 (i=50)
# Warning: Newton did not converge at t=28.3 (i=50)
# Warning: Newton did not converge at t=28.400000000000002 (i=50)
# Warning: Newton did not converge at t=28.5 (i=50)
# Warning: Newton did not converge at t=28.6 (i=50)
# Warning: Newton did not converge at t=28.700000000000003 (i=50)
# Warning: Newton did not converge at t=28.8 (i=50)
# Warning: Newton did not converge at t=28.900000000000002 (i=50)
# Warning: Newton did not converge at t=29.0 (i=50)
# Warning: Newton did not converge at t=29.1 (i=50)
# Warning: Newton did not converge at t=29.200000000000003 (i=50)
# Warning: Newton did not converge at t=29.3 (i=50)
# Warning: Newton did not converge at t=29.400000000000002 (i=50)
# Warning: Newton did not converge at t=29.5 (i=50)
# Warning: Newton did not converge at t=29.6 (i=50)
# Warning: Newton did not converge at t=29.700000000000003 (i=50)
# Warning: Newton did not converge at t=29.8 (i=50)
# Warning: Newton did not converge at t=29.900000000000002 (i=50)
# Warning: Newton did not converge at t=30.0 (i=50)
# Warning: Newton did not converge at t=30.1 (i=50)
# Warning: Newton did not converge at t=30.200000000000003 (i=50)
# Warning: Newton did not converge at t=30.3 (i=50)
# Warning: Newton did not converge at t=30.400000000000002 (i=50)
# Warning: Newton did not converge at t=30.5 (i=50)
# Warning: Newton did not converge at t=30.6 (i=50)
# Warning: Newton did not converge at t=30.700000000000003 (i=50)
# Warning: Newton did not converge at t=30.8 (i=50)
# Warning: Newton did not converge at t=30.900000000000002 (i=50)
# Warning: Newton did not converge at t=31.0 (i=50)
# Warning: Newton did not converge at t=31.1 (i=50)
# Warning: Newton did not converge at t=31.200000000000003 (i=50)
# Warning: Newton did not converge at t=31.3 (i=50)
# Warning: Newton did not converge at t=31.400000000000002 (i=50)
# Warning: Newton did not converge at t=31.5 (i=50)
# Warning: Newton did not converge at t=31.6 (i=50)
# Warning: Newton did not converge at t=31.700000000000003 (i=50)
# Warning: Newton did not converge at t=31.8 (i=50)
# Warning: Newton did not converge at t=31.900000000000002 (i=50)
# Warning: Newton did not converge at t=32.0 (i=50)
# Warning: Newton did not converge at t=32.1 (i=50)
# Warning: Newton did not converge at t=32.2 (i=50)
# Warning: Newton did not converge at t=32.300000000000004 (i=50)
# Warning: Newton did not converge at t=32.4 (i=50)
# Warning: Newton did not converge at t=32.5 (i=50)
# Warning: Newton did not converge at t=32.6 (i=50)
# Warning: Newton did not converge at t=32.7 (i=50)
# Warning: Newton did not converge at t=32.800000000000004 (i=50)
# Warning: Newton did not converge at t=32.9 (i=50)
# Warning: Newton did not converge at t=33.0 (i=50)
# Warning: Newton did not converge at t=33.1 (i=50)
# Warning: Newton did not converge at t=33.2 (i=50)
# Warning: Newton did not converge at t=33.300000000000004 (i=50)
# Warning: Newton did not converge at t=33.4 (i=50)
# Warning: Newton did not converge at t=33.5 (i=50)
# Warning: Newton did not converge at t=33.6 (i=50)
# Warning: Newton did not converge at t=33.7 (i=50)
# Warning: Newton did not converge at t=33.800000000000004 (i=50)
# Warning: Newton did not converge at t=33.9 (i=50)
# Warning: Newton did not converge at t=34.0 (i=50)
# Warning: Newton did not converge at t=34.1 (i=50)
# Warning: Newton did not converge at t=34.2 (i=50)
# Warning: Newton did not converge at t=34.300000000000004 (i=50)
# Warning: Newton did not converge at t=34.4 (i=50)
# Warning: Newton did not converge at t=34.5 (i=50)
# Warning: Newton did not converge at t=34.6 (i=50)
# Warning: Newton did not converge at t=34.7 (i=50)
# Warning: Newton did not converge at t=34.800000000000004 (i=50)
# Warning: Newton did not converge at t=34.9 (i=50)
# Warning: Newton did not converge at t=35.0 (i=50)
# Warning: Newton did not converge at t=35.1 (i=50)
# Warning: Newton did not converge at t=35.2 (i=50)
# Warning: Newton did not converge at t=35.300000000000004 (i=50)
# Warning: Newton did not converge at t=35.4 (i=50)
# Warning: Newton did not converge at t=35.5 (i=50)
# Warning: Newton did not converge at t=35.6 (i=50)
# Warning: Newton did not converge at t=35.7 (i=50)
# Warning: Newton did not converge at t=35.800000000000004 (i=50)
# Warning: Newton did not converge at t=35.9 (i=50)
# Warning: Newton did not converge at t=36.0 (i=50)
# Warning: Newton did not converge at t=36.1 (i=50)
# Warning: Newton did not converge at t=36.2 (i=50)
# Warning: Newton did not converge at t=36.300000000000004 (i=50)
# Warning: Newton did not converge at t=36.4 (i=50)
# Warning: Newton did not converge at t=36.5 (i=50)
# Warning: Newton did not converge at t=36.6 (i=50)
# Warning: Newton did not converge at t=36.7 (i=50)
# Warning: Newton did not converge at t=36.800000000000004 (i=50)
# Warning: Newton did not converge at t=36.9 (i=50)
# Warning: Newton did not converge at t=37.0 (i=50)
# Warning: Newton did not converge at t=37.1 (i=50)
# Warning: Newton did not converge at t=37.2 (i=50)
# Warning: Newton did not converge at t=37.300000000000004 (i=50)
# Warning: Newton did not converge at t=37.4 (i=50)
# Warning: Newton did not converge at t=37.5 (i=50)
# Warning: Newton did not converge at t=37.6 (i=50)
# Warning: Newton did not converge at t=37.7 (i=50)
# Warning: Newton did not converge at t=37.800000000000004 (i=50)
# Warning: Newton did not converge at t=37.9 (i=50)
# Warning: Newton did not converge at t=38.0 (i=50)
# Warning: Newton did not converge at t=38.1 (i=50)
# Warning: Newton did not converge at t=38.2 (i=50)
# Warning: Newton did not converge at t=38.300000000000004 (i=50)
# Warning: Newton did not converge at t=38.400000000000006 (i=50)
# Warning: Newton did not converge at t=38.5 (i=50)
# Warning: Newton did not converge at t=38.6 (i=50)
# Warning: Newton did not converge at t=38.7 (i=50)
# Warning: Newton did not converge at t=38.800000000000004 (i=50)
# Warning: Newton did not converge at t=38.900000000000006 (i=50)
# Warning: Newton did not converge at t=39.0 (i=50)
# Warning: Newton did not converge at t=39.1 (i=50)
# Warning: Newton did not converge at t=39.2 (i=50)
# Warning: Newton did not converge at t=39.300000000000004 (i=50)
# Warning: Newton did not converge at t=39.400000000000006 (i=50)
# Warning: Newton did not converge at t=39.5 (i=50)
# Warning: Newton did not converge at t=39.6 (i=50)
# Warning: Newton did not converge at t=39.7 (i=50)
# Warning: Newton did not converge at t=39.800000000000004 (i=50)
# Warning: Newton did not converge at t=39.900000000000006 (i=50)
# Warning: Newton did not converge at t=40.0 (i=50)
# Warning: Newton did not converge at t=40.1 (i=50)
# Warning: Newton did not converge at t=40.2 (i=50)
# Warning: Newton did not converge at t=40.300000000000004 (i=50)
# Warning: Newton did not converge at t=40.400000000000006 (i=50)
# Warning: Newton did not converge at t=40.5 (i=50)
# Warning: Newton did not converge at t=40.6 (i=50)
# Warning: Newton did not converge at t=40.7 (i=50)
# Warning: Newton did not converge at t=40.800000000000004 (i=50)
# Warning: Newton did not converge at t=40.900000000000006 (i=50)
# Warning: Newton did not converge at t=41.0 (i=50)
# Warning: Newton did not converge at t=41.1 (i=50)
# Warning: Newton did not converge at t=41.2 (i=50)
# Warning: Newton did not converge at t=41.300000000000004 (i=50)
# Warning: Newton did not converge at t=41.400000000000006 (i=50)
# Warning: Newton did not converge at t=41.5 (i=50)
# Warning: Newton did not converge at t=41.6 (i=50)
# Warning: Newton did not converge at t=41.7 (i=50)
# Warning: Newton did not converge at t=41.800000000000004 (i=50)
# Warning: Newton did not converge at t=41.900000000000006 (i=50)
# Warning: Newton did not converge at t=42.0 (i=50)
# Warning: Newton did not converge at t=42.1 (i=50)
# Warning: Newton did not converge at t=42.2 (i=50)
# Warning: Newton did not converge at t=42.300000000000004 (i=50)
# Warning: Newton did not converge at t=42.400000000000006 (i=50)
# Warning: Newton did not converge at t=42.5 (i=50)
# Warning: Newton did not converge at t=42.6 (i=50)
# Warning: Newton did not converge at t=42.7 (i=50)
# Warning: Newton did not converge at t=42.800000000000004 (i=50)
# Warning: Newton did not converge at t=42.900000000000006 (i=50)
# Warning: Newton did not converge at t=43.0 (i=50)
# Warning: Newton did not converge at t=43.1 (i=50)
# Warning: Newton did not converge at t=43.2 (i=50)
# Warning: Newton did not converge at t=43.300000000000004 (i=50)
# Warning: Newton did not converge at t=43.400000000000006 (i=50)
# Warning: Newton did not converge at t=43.5 (i=50)
# Warning: Newton did not converge at t=43.6 (i=50)
# Warning: Newton did not converge at t=43.7 (i=50)
# Warning: Newton did not converge at t=43.800000000000004 (i=50)
# Warning: Newton did not converge at t=43.900000000000006 (i=50)
# Warning: Newton did not converge at t=44.0 (i=50)
# Warning: Newton did not converge at t=44.1 (i=50)
# Warning: Newton did not converge at t=44.2 (i=50)
# Warning: Newton did not converge at t=44.300000000000004 (i=50)
# Warning: Newton did not converge at t=44.400000000000006 (i=50)
# Warning: Newton did not converge at t=44.5 (i=50)
# Warning: Newton did not converge at t=44.6 (i=50)
# Warning: Newton did not converge at t=44.7 (i=50)
# Warning: Newton did not converge at t=44.800000000000004 (i=50)
# Warning: Newton did not converge at t=44.900000000000006 (i=50)
# Warning: Newton did not converge at t=45.0 (i=50)
# Warning: Newton did not converge at t=45.1 (i=50)
# Warning: Newton did not converge at t=45.2 (i=50)
# Warning: Newton did not converge at t=45.300000000000004 (i=50)
# Warning: Newton did not converge at t=45.400000000000006 (i=50)
# Warning: Newton did not converge at t=45.5 (i=50)
# Warning: Newton did not converge at t=45.6 (i=50)
# Warning: Newton did not converge at t=45.7 (i=50)
# Warning: Newton did not converge at t=45.800000000000004 (i=50)
# Warning: Newton did not converge at t=45.900000000000006 (i=50)
# Warning: Newton did not converge at t=46.0 (i=50)
# Warning: Newton did not converge at t=46.1 (i=50)
# Warning: Newton did not converge at t=46.2 (i=50)
# Warning: Newton did not converge at t=46.300000000000004 (i=50)
# Warning: Newton did not converge at t=46.400000000000006 (i=50)
# Warning: Newton did not converge at t=46.5 (i=50)
# Warning: Newton did not converge at t=46.6 (i=50)
# Warning: Newton did not converge at t=46.7 (i=50)
# Warning: Newton did not converge at t=46.800000000000004 (i=50)
# Warning: Newton did not converge at t=46.900000000000006 (i=50)
# Warning: Newton did not converge at t=47.0 (i=50)
# Warning: Newton did not converge at t=47.1 (i=50)
# Warning: Newton did not converge at t=47.2 (i=50)
# Warning: Newton did not converge at t=47.300000000000004 (i=50)
# Warning: Newton did not converge at t=47.400000000000006 (i=50)
# Warning: Newton did not converge at t=47.5 (i=50)
# Warning: Newton did not converge at t=47.6 (i=50)
# Warning: Newton did not converge at t=47.7 (i=50)
# Warning: Newton did not converge at t=47.800000000000004 (i=50)
# Warning: Newton did not converge at t=47.900000000000006 (i=50)
# Warning: Newton did not converge at t=48.0 (i=50)
# Warning: Newton did not converge at t=48.1 (i=50)
# Warning: Newton did not converge at t=48.2 (i=50)
# Warning: Newton did not converge at t=48.300000000000004 (i=50)
# Warning: Newton did not converge at t=48.400000000000006 (i=50)
# Warning: Newton did not converge at t=48.5 (i=50)
# Warning: Newton did not converge at t=48.6 (i=50)
# Warning: Newton did not converge at t=48.7 (i=50)
# Warning: Newton did not converge at t=48.800000000000004 (i=50)
# Warning: Newton did not converge at t=48.900000000000006 (i=50)
# Warning: Newton did not converge at t=49.0 (i=50)
# Warning: Newton did not converge at t=49.1 (i=50)
# Warning: Newton did not converge at t=49.2 (i=50)
# Warning: Newton did not converge at t=49.300000000000004 (i=50)
# Warning: Newton did not converge at t=49.400000000000006 (i=50)
# Warning: Newton did not converge at t=49.5 (i=50)
# Warning: Newton did not converge at t=49.6 (i=50)
# Warning: Newton did not converge at t=49.7 (i=50)
# Warning: Newton did not converge at t=49.800000000000004 (i=50)
# Warning: Newton did not converge at t=49.900000000000006 (i=50)
# Warning: Newton did not converge at t=50.0 (i=50)
# Warning: Newton did not converge at t=50.1 (i=50)
# Warning: Newton did not converge at t=50.2 (i=50)
# Warning: Newton did not converge at t=50.300000000000004 (i=50)
# Warning: Newton did not converge at t=50.400000000000006 (i=50)
# Warning: Newton did not converge at t=50.5 (i=50)
# Warning: Newton did not converge at t=50.6 (i=50)
# Warning: Newton did not converge at t=50.7 (i=50)
# Warning: Newton did not converge at t=50.800000000000004 (i=50)
# Warning: Newton did not converge at t=50.900000000000006 (i=50)
# Warning: Newton did not converge at t=51.0 (i=50)
# Warning: Newton did not converge at t=51.1 (i=50)
# Warning: Newton did not converge at t=51.2 (i=50)
# Warning: Newton did not converge at t=51.300000000000004 (i=50)
# Warning: Newton did not converge at t=51.400000000000006 (i=50)
# Warning: Newton did not converge at t=51.5 (i=50)
# Warning: Newton did not converge at t=51.6 (i=50)
# Warning: Newton did not converge at t=51.7 (i=50)
# Warning: Newton did not converge at t=51.800000000000004 (i=50)
# Warning: Newton did not converge at t=51.900000000000006 (i=50)
# Warning: Newton did not converge at t=52.0 (i=50)
# Warning: Newton did not converge at t=52.1 (i=50)
# Warning: Newton did not converge at t=52.2 (i=50)
# Warning: Newton did not converge at t=52.300000000000004 (i=50)
# Warning: Newton did not converge at t=52.400000000000006 (i=50)
# Warning: Newton did not converge at t=52.5 (i=50)
# Warning: Newton did not converge at t=52.6 (i=50)
# Warning: Newton did not converge at t=52.7 (i=50)
# Warning: Newton did not converge at t=52.800000000000004 (i=50)
# Warning: Newton did not converge at t=52.900000000000006 (i=50)
# Warning: Newton did not converge at t=53.0 (i=50)
# Warning: Newton did not converge at t=53.1 (i=50)
# Warning: Newton did not converge at t=53.2 (i=50)
# Warning: Newton did not converge at t=53.300000000000004 (i=50)
# Warning: Newton did not converge at t=53.400000000000006 (i=50)
# Warning: Newton did not converge at t=53.5 (i=50)
# Warning: Newton did not converge at t=53.6 (i=50)
# Warning: Newton did not converge at t=53.7 (i=50)
# Warning: Newton did not converge at t=53.800000000000004 (i=50)
# Warning: Newton did not converge at t=53.900000000000006 (i=50)
# Warning: Newton did not converge at t=54.0 (i=50)
# Warning: Newton did not converge at t=54.1 (i=50)
# Warning: Newton did not converge at t=54.2 (i=50)
# Warning: Newton did not converge at t=54.300000000000004 (i=50)
# Warning: Newton did not converge at t=54.400000000000006 (i=50)
# Warning: Newton did not converge at t=54.5 (i=50)
# Warning: Newton did not converge at t=54.6 (i=50)
# Warning: Newton did not converge at t=54.7 (i=50)
# Warning: Newton did not converge at t=54.800000000000004 (i=50)
# Warning: Newton did not converge at t=54.900000000000006 (i=50)
# Warning: Newton did not converge at t=55.0 (i=50)
# Warning: Newton did not converge at t=55.1 (i=50)
# Warning: Newton did not converge at t=55.2 (i=50)
# Warning: Newton did not converge at t=55.300000000000004 (i=50)
# Warning: Newton did not converge at t=55.400000000000006 (i=50)
# Warning: Newton did not converge at t=55.5 (i=50)
# Warning: Newton did not converge at t=55.6 (i=50)
# Warning: Newton did not converge at t=55.7 (i=50)
# Warning: Newton did not converge at t=55.800000000000004 (i=50)
# Warning: Newton did not converge at t=55.900000000000006 (i=50)
# Warning: Newton did not converge at t=56.0 (i=50)
# Warning: Newton did not converge at t=56.1 (i=50)
# Warning: Newton did not converge at t=56.2 (i=50)
# Warning: Newton did not converge at t=56.300000000000004 (i=50)
# Warning: Newton did not converge at t=56.400000000000006 (i=50)
# Warning: Newton did not converge at t=56.5 (i=50)
# Warning: Newton did not converge at t=56.6 (i=50)
# Warning: Newton did not converge at t=56.7 (i=50)
# Warning: Newton did not converge at t=56.800000000000004 (i=50)
# Warning: Newton did not converge at t=56.900000000000006 (i=50)
# Warning: Newton did not converge at t=57.0 (i=50)
# Warning: Newton did not converge at t=57.1 (i=50)
# Warning: Newton did not converge at t=57.2 (i=50)
# Warning: Newton did not converge at t=57.300000000000004 (i=50)
# Warning: Newton did not converge at t=57.400000000000006 (i=50)
# Warning: Newton did not converge at t=57.5 (i=50)
# Warning: Newton did not converge at t=57.6 (i=50)
# Warning: Newton did not converge at t=57.7 (i=50)
# Warning: Newton did not converge at t=57.800000000000004 (i=50)
# Warning: Newton did not converge at t=57.900000000000006 (i=50)
# Warning: Newton did not converge at t=58.0 (i=50)
# Warning: Newton did not converge at t=58.1 (i=50)
# Warning: Newton did not converge at t=58.2 (i=50)
# Warning: Newton did not converge at t=58.300000000000004 (i=50)
# Warning: Newton did not converge at t=58.400000000000006 (i=50)
# Warning: Newton did not converge at t=58.5 (i=50)
# Warning: Newton did not converge at t=58.6 (i=50)
# Warning: Newton did not converge at t=58.7 (i=50)
# Warning: Newton did not converge at t=58.800000000000004 (i=50)
# Warning: Newton did not converge at t=58.900000000000006 (i=50)
# Warning: Newton did not converge at t=59.0 (i=50)
# Warning: Newton did not converge at t=59.1 (i=50)
# Warning: Newton did not converge at t=59.2 (i=50)
# Warning: Newton did not converge at t=59.300000000000004 (i=50)
# Warning: Newton did not converge at t=59.400000000000006 (i=50)
# Warning: Newton did not converge at t=59.5 (i=50)
# Warning: Newton did not converge at t=59.6 (i=50)
# Warning: Newton did not converge at t=59.7 (i=50)
# Warning: Newton did not converge at t=59.800000000000004 (i=50)
# Warning: Newton did not converge at t=59.900000000000006 (i=50)
# Warning: Newton did not converge at t=60.0 (i=50)
# Warning: Newton did not converge at t=60.1 (i=50)
# Warning: Newton did not converge at t=60.2 (i=50)
# Warning: Newton did not converge at t=60.300000000000004 (i=50)
# Warning: Newton did not converge at t=60.400000000000006 (i=50)
# Warning: Newton did not converge at t=60.5 (i=50)
# Warning: Newton did not converge at t=60.6 (i=50)
# Warning: Newton did not converge at t=60.7 (i=50)
# Warning: Newton did not converge at t=60.800000000000004 (i=50)
# Warning: Newton did not converge at t=60.900000000000006 (i=50)
# Warning: Newton did not converge at t=61.0 (i=50)
# Warning: Newton did not converge at t=61.1 (i=50)
# Warning: Newton did not converge at t=61.2 (i=50)
# Warning: Newton did not converge at t=61.300000000000004 (i=50)
# Warning: Newton did not converge at t=61.400000000000006 (i=50)
# Warning: Newton did not converge at t=61.5 (i=50)
# Warning: Newton did not converge at t=61.6 (i=50)
# Warning: Newton did not converge at t=61.7 (i=50)
# Warning: Newton did not converge at t=61.800000000000004 (i=50)
# Warning: Newton did not converge at t=61.900000000000006 (i=50)
# Warning: Newton did not converge at t=62.0 (i=50)
# Warning: Newton did not converge at t=62.1 (i=50)
# Warning: Newton did not converge at t=62.2 (i=50)
# Warning: Newton did not converge at t=62.300000000000004 (i=50)
# Warning: Newton did not converge at t=62.400000000000006 (i=50)
# Warning: Newton did not converge at t=62.5 (i=50)
# Warning: Newton did not converge at t=62.6 (i=50)
# Warning: Newton did not converge at t=62.7 (i=50)
# Warning: Newton did not converge at t=62.800000000000004 (i=50)
# Warning: Newton did not converge at t=62.900000000000006 (i=50)
# Warning: Newton did not converge at t=63.0 (i=50)
# Warning: Newton did not converge at t=63.1 (i=50)
# Warning: Newton did not converge at t=63.2 (i=50)
# Warning: Newton did not converge at t=63.300000000000004 (i=50)
# Warning: Newton did not converge at t=63.400000000000006 (i=50)
# Warning: Newton did not converge at t=63.5 (i=50)
# Warning: Newton did not converge at t=63.6 (i=50)
# Warning: Newton did not converge at t=63.7 (i=50)
# Warning: Newton did not converge at t=63.800000000000004 (i=50)
# Warning: Newton did not converge at t=63.900000000000006 (i=50)
# Warning: Newton did not converge at t=64.0 (i=50)
# Warning: Newton did not converge at t=64.10000000000001 (i=50)
# Warning: Newton did not converge at t=64.2 (i=50)
# Warning: Newton did not converge at t=64.3 (i=50)
# Warning: Newton did not converge at t=64.4 (i=50)
# Warning: Newton did not converge at t=64.5 (i=50)
# Warning: Newton did not converge at t=64.60000000000001 (i=50)
# Warning: Newton did not converge at t=64.7 (i=50)
# Warning: Newton did not converge at t=64.8 (i=50)
# Warning: Newton did not converge at t=64.9 (i=50)
# Warning: Newton did not converge at t=65.0 (i=50)
# Warning: Newton did not converge at t=65.10000000000001 (i=50)
# Warning: Newton did not converge at t=65.2 (i=50)
# Warning: Newton did not converge at t=65.3 (i=50)
# Warning: Newton did not converge at t=65.4 (i=50)
# Warning: Newton did not converge at t=65.5 (i=50)
# Warning: Newton did not converge at t=65.60000000000001 (i=50)
# Warning: Newton did not converge at t=65.7 (i=50)
# Warning: Newton did not converge at t=65.8 (i=50)
# Warning: Newton did not converge at t=65.9 (i=50)
# Warning: Newton did not converge at t=66.0 (i=50)
# Warning: Newton did not converge at t=66.10000000000001 (i=50)
# Warning: Newton did not converge at t=66.2 (i=50)
# Warning: Newton did not converge at t=66.3 (i=50)
# Warning: Newton did not converge at t=66.4 (i=50)
# Warning: Newton did not converge at t=66.5 (i=50)
# Warning: Newton did not converge at t=66.60000000000001 (i=50)
# Warning: Newton did not converge at t=66.7 (i=50)
# Warning: Newton did not converge at t=66.8 (i=50)
# Warning: Newton did not converge at t=66.9 (i=50)
# Warning: Newton did not converge at t=67.0 (i=50)
# Warning: Newton did not converge at t=67.10000000000001 (i=50)
# Warning: Newton did not converge at t=67.2 (i=50)
# Warning: Newton did not converge at t=67.3 (i=50)
# Warning: Newton did not converge at t=67.4 (i=50)
# Warning: Newton did not converge at t=67.5 (i=50)
# Warning: Newton did not converge at t=67.60000000000001 (i=50)
# Warning: Newton did not converge at t=67.7 (i=50)
# Warning: Newton did not converge at t=67.8 (i=50)
# Warning: Newton did not converge at t=67.9 (i=50)
# Warning: Newton did not converge at t=68.0 (i=50)
# Warning: Newton did not converge at t=68.10000000000001 (i=50)
# Warning: Newton did not converge at t=68.2 (i=50)
# Warning: Newton did not converge at t=68.3 (i=50)
# Warning: Newton did not converge at t=68.4 (i=50)
# Warning: Newton did not converge at t=68.5 (i=50)
# Warning: Newton did not converge at t=68.60000000000001 (i=50)
# Warning: Newton did not converge at t=68.7 (i=50)
# Warning: Newton did not converge at t=68.8 (i=50)
# Warning: Newton did not converge at t=68.9 (i=50)
# Warning: Newton did not converge at t=69.0 (i=50)
# Warning: Newton did not converge at t=69.10000000000001 (i=50)
# Warning: Newton did not converge at t=69.2 (i=50)
# Warning: Newton did not converge at t=69.3 (i=50)
# Warning: Newton did not converge at t=69.4 (i=50)
# Warning: Newton did not converge at t=69.5 (i=50)
# Warning: Newton did not converge at t=69.60000000000001 (i=50)
# Warning: Newton did not converge at t=69.7 (i=50)
# Warning: Newton did not converge at t=69.8 (i=50)
# Warning: Newton did not converge at t=69.9 (i=50)
# Warning: Newton did not converge at t=70.0 (i=50)
# Warning: Newton did not converge at t=70.10000000000001 (i=50)
# Warning: Newton did not converge at t=70.2 (i=50)
# Warning: Newton did not converge at t=70.3 (i=50)
# Warning: Newton did not converge at t=70.4 (i=50)
# Warning: Newton did not converge at t=70.5 (i=50)
# Warning: Newton did not converge at t=70.60000000000001 (i=50)
# Warning: Newton did not converge at t=70.7 (i=50)
# Warning: Newton did not converge at t=70.8 (i=50)
# Warning: Newton did not converge at t=70.9 (i=50)
# Warning: Newton did not converge at t=71.0 (i=50)
# Warning: Newton did not converge at t=71.10000000000001 (i=50)
# Warning: Newton did not converge at t=71.2 (i=50)
# Warning: Newton did not converge at t=71.3 (i=50)
# Warning: Newton did not converge at t=71.4 (i=50)
# Warning: Newton did not converge at t=71.5 (i=50)
# Warning: Newton did not converge at t=71.60000000000001 (i=50)
# Warning: Newton did not converge at t=71.7 (i=50)
# Warning: Newton did not converge at t=71.8 (i=50)
# Warning: Newton did not converge at t=71.9 (i=50)
# Warning: Newton did not converge at t=72.0 (i=50)
# Warning: Newton did not converge at t=72.10000000000001 (i=50)
# Warning: Newton did not converge at t=72.2 (i=50)
# Warning: Newton did not converge at t=72.3 (i=50)
# Warning: Newton did not converge at t=72.4 (i=50)
# Warning: Newton did not converge at t=72.5 (i=50)
# Warning: Newton did not converge at t=72.60000000000001 (i=50)
# Warning: Newton did not converge at t=72.7 (i=50)
# Warning: Newton did not converge at t=72.8 (i=50)
# Warning: Newton did not converge at t=72.9 (i=50)
# Warning: Newton did not converge at t=73.0 (i=50)
# Warning: Newton did not converge at t=73.10000000000001 (i=50)
# Warning: Newton did not converge at t=73.2 (i=50)
# Warning: Newton did not converge at t=73.3 (i=50)
# Warning: Newton did not converge at t=73.4 (i=50)
# Warning: Newton did not converge at t=73.5 (i=50)
# Warning: Newton did not converge at t=73.60000000000001 (i=50)
# Warning: Newton did not converge at t=73.7 (i=50)
# Warning: Newton did not converge at t=73.8 (i=50)
# Warning: Newton did not converge at t=73.9 (i=50)
# Warning: Newton did not converge at t=74.0 (i=50)
# Warning: Newton did not converge at t=74.10000000000001 (i=50)
# Warning: Newton did not converge at t=74.2 (i=50)
# Warning: Newton did not converge at t=74.3 (i=50)
# Warning: Newton did not converge at t=74.4 (i=50)
# Warning: Newton did not converge at t=74.5 (i=50)
# Warning: Newton did not converge at t=74.60000000000001 (i=50)
# Warning: Newton did not converge at t=74.7 (i=50)
# Warning: Newton did not converge at t=74.8 (i=50)
# Warning: Newton did not converge at t=74.9 (i=50)
# Warning: Newton did not converge at t=75.0 (i=50)
# Warning: Newton did not converge at t=75.10000000000001 (i=50)
# Warning: Newton did not converge at t=75.2 (i=50)
# Warning: Newton did not converge at t=75.3 (i=50)
# Warning: Newton did not converge at t=75.4 (i=50)
# Warning: Newton did not converge at t=75.5 (i=50)
# Warning: Newton did not converge at t=75.60000000000001 (i=50)
# Warning: Newton did not converge at t=75.7 (i=50)
# Warning: Newton did not converge at t=75.8 (i=50)
# Warning: Newton did not converge at t=75.9 (i=50)
# Warning: Newton did not converge at t=76.0 (i=50)
# Warning: Newton did not converge at t=76.10000000000001 (i=50)
# Warning: Newton did not converge at t=76.2 (i=50)
# Warning: Newton did not converge at t=76.3 (i=50)
# Warning: Newton did not converge at t=76.4 (i=50)
# Warning: Newton did not converge at t=76.5 (i=50)
# Warning: Newton did not converge at t=76.60000000000001 (i=50)
# Warning: Newton did not converge at t=76.7 (i=50)
# Warning: Newton did not converge at t=76.80000000000001 (i=50)
# Warning: Newton did not converge at t=76.9 (i=50)
# Warning: Newton did not converge at t=77.0 (i=50)
# Warning: Newton did not converge at t=77.10000000000001 (i=50)
# Warning: Newton did not converge at t=77.2 (i=50)
# Warning: Newton did not converge at t=77.30000000000001 (i=50)
# Warning: Newton did not converge at t=77.4 (i=50)
# Warning: Newton did not converge at t=77.5 (i=50)
# Warning: Newton did not converge at t=77.60000000000001 (i=50)
# Warning: Newton did not converge at t=77.7 (i=50)
# Warning: Newton did not converge at t=77.80000000000001 (i=50)
# Warning: Newton did not converge at t=77.9 (i=50)
# Warning: Newton did not converge at t=78.0 (i=50)
# Warning: Newton did not converge at t=78.10000000000001 (i=50)
# Warning: Newton did not converge at t=78.2 (i=50)
# Warning: Newton did not converge at t=78.30000000000001 (i=50)
# Warning: Newton did not converge at t=78.4 (i=50)
# Warning: Newton did not converge at t=78.5 (i=50)
# Warning: Newton did not converge at t=78.60000000000001 (i=50)
# Warning: Newton did not converge at t=78.7 (i=50)
# Warning: Newton did not converge at t=78.80000000000001 (i=50)
# Warning: Newton did not converge at t=78.9 (i=50)
# Warning: Newton did not converge at t=79.0 (i=50)
# Warning: Newton did not converge at t=79.10000000000001 (i=50)
# Warning: Newton did not converge at t=79.2 (i=50)
# Warning: Newton did not converge at t=79.30000000000001 (i=50)
# Warning: Newton did not converge at t=79.4 (i=50)
# Warning: Newton did not converge at t=79.5 (i=50)
# Warning: Newton did not converge at t=79.60000000000001 (i=50)
# Warning: Newton did not converge at t=79.7 (i=50)
# Warning: Newton did not converge at t=79.80000000000001 (i=50)
# Warning: Newton did not converge at t=79.9 (i=50)
# Warning: Newton did not converge at t=80.0 (i=50)
# Warning: Newton did not converge at t=80.10000000000001 (i=50)
# Warning: Newton did not converge at t=80.2 (i=50)
# Warning: Newton did not converge at t=80.30000000000001 (i=50)
# Warning: Newton did not converge at t=80.4 (i=50)
# Warning: Newton did not converge at t=80.5 (i=50)
# Warning: Newton did not converge at t=80.60000000000001 (i=50)
# Warning: Newton did not converge at t=80.7 (i=50)
# Warning: Newton did not converge at t=80.80000000000001 (i=50)
# Warning: Newton did not converge at t=80.9 (i=50)
# Warning: Newton did not converge at t=81.0 (i=50)
# Warning: Newton did not converge at t=81.10000000000001 (i=50)
# Warning: Newton did not converge at t=81.2 (i=50)
# Warning: Newton did not converge at t=81.30000000000001 (i=50)
# Warning: Newton did not converge at t=81.4 (i=50)
# Warning: Newton did not converge at t=81.5 (i=50)
# Warning: Newton did not converge at t=81.60000000000001 (i=50)
# Warning: Newton did not converge at t=81.7 (i=50)
# Warning: Newton did not converge at t=81.80000000000001 (i=50)
# Warning: Newton did not converge at t=81.9 (i=50)
# Warning: Newton did not converge at t=82.0 (i=50)
# Warning: Newton did not converge at t=82.10000000000001 (i=50)
# Warning: Newton did not converge at t=82.2 (i=50)
# Warning: Newton did not converge at t=82.30000000000001 (i=50)
# Warning: Newton did not converge at t=82.4 (i=50)
# Warning: Newton did not converge at t=82.5 (i=50)
# Warning: Newton did not converge at t=82.60000000000001 (i=50)
# Warning: Newton did not converge at t=82.7 (i=50)
# Warning: Newton did not converge at t=82.80000000000001 (i=50)
# Warning: Newton did not converge at t=82.9 (i=50)
# Warning: Newton did not converge at t=83.0 (i=50)
# Warning: Newton did not converge at t=83.10000000000001 (i=50)
# Warning: Newton did not converge at t=83.2 (i=50)
# Warning: Newton did not converge at t=83.30000000000001 (i=50)
# Warning: Newton did not converge at t=83.4 (i=50)
# Warning: Newton did not converge at t=83.5 (i=50)
# Warning: Newton did not converge at t=83.60000000000001 (i=50)
# Warning: Newton did not converge at t=83.7 (i=50)
# Warning: Newton did not converge at t=83.80000000000001 (i=50)
# Warning: Newton did not converge at t=83.9 (i=50)
# Warning: Newton did not converge at t=84.0 (i=50)
# Warning: Newton did not converge at t=84.10000000000001 (i=50)
# Warning: Newton did not converge at t=84.2 (i=50)
# Warning: Newton did not converge at t=84.30000000000001 (i=50)
# Warning: Newton did not converge at t=84.4 (i=50)
# Warning: Newton did not converge at t=84.5 (i=50)
# Warning: Newton did not converge at t=84.60000000000001 (i=50)
# Warning: Newton did not converge at t=84.7 (i=50)
# Warning: Newton did not converge at t=84.80000000000001 (i=50)
# Warning: Newton did not converge at t=84.9 (i=50)
# Warning: Newton did not converge at t=85.0 (i=50)
# Warning: Newton did not converge at t=85.10000000000001 (i=50)
# Warning: Newton did not converge at t=85.2 (i=50)
# Warning: Newton did not converge at t=85.30000000000001 (i=50)
# Warning: Newton did not converge at t=85.4 (i=50)
# Warning: Newton did not converge at t=85.5 (i=50)
# Warning: Newton did not converge at t=85.60000000000001 (i=50)
# Warning: Newton did not converge at t=85.7 (i=50)
# Warning: Newton did not converge at t=85.80000000000001 (i=50)
# Warning: Newton did not converge at t=85.9 (i=50)
# Warning: Newton did not converge at t=86.0 (i=50)
# Warning: Newton did not converge at t=86.10000000000001 (i=50)
# Warning: Newton did not converge at t=86.2 (i=50)
# Warning: Newton did not converge at t=86.30000000000001 (i=50)
# Warning: Newton did not converge at t=86.4 (i=50)
# Warning: Newton did not converge at t=86.5 (i=50)
# Warning: Newton did not converge at t=86.60000000000001 (i=50)
# Warning: Newton did not converge at t=86.7 (i=50)
# Warning: Newton did not converge at t=86.80000000000001 (i=50)
# Warning: Newton did not converge at t=86.9 (i=50)
# Warning: Newton did not converge at t=87.0 (i=50)
# Warning: Newton did not converge at t=87.10000000000001 (i=50)
# Warning: Newton did not converge at t=87.2 (i=50)
# Warning: Newton did not converge at t=87.30000000000001 (i=50)
# Warning: Newton did not converge at t=87.4 (i=50)
# Warning: Newton did not converge at t=87.5 (i=50)
# Warning: Newton did not converge at t=87.60000000000001 (i=50)
# Warning: Newton did not converge at t=87.7 (i=50)
# Warning: Newton did not converge at t=87.80000000000001 (i=50)
# Warning: Newton did not converge at t=87.9 (i=50)
# Warning: Newton did not converge at t=88.0 (i=50)
# Warning: Newton did not converge at t=88.10000000000001 (i=50)
# Warning: Newton did not converge at t=88.2 (i=50)
# Warning: Newton did not converge at t=88.30000000000001 (i=50)
# Warning: Newton did not converge at t=88.4 (i=50)
# Warning: Newton did not converge at t=88.5 (i=50)
# Warning: Newton did not converge at t=88.60000000000001 (i=50)
# Warning: Newton did not converge at t=88.7 (i=50)
# Warning: Newton did not converge at t=88.80000000000001 (i=50)
# Warning: Newton did not converge at t=88.9 (i=50)
# Warning: Newton did not converge at t=89.0 (i=50)
# Warning: Newton did not converge at t=89.10000000000001 (i=50)
# Warning: Newton did not converge at t=89.2 (i=50)
# Warning: Newton did not converge at t=89.30000000000001 (i=50)
# Warning: Newton did not converge at t=89.4 (i=50)
# Warning: Newton did not converge at t=89.5 (i=50)
# Warning: Newton did not converge at t=89.60000000000001 (i=50)
# Warning: Newton did not converge at t=89.7 (i=50)
# Warning: Newton did not converge at t=89.80000000000001 (i=50)
# Warning: Newton did not converge at t=89.9 (i=50)
# Warning: Newton did not converge at t=90.0 (i=50)
# Warning: Newton did not converge at t=90.10000000000001 (i=50)
# Warning: Newton did not converge at t=90.2 (i=50)
# Warning: Newton did not converge at t=90.30000000000001 (i=50)
# Warning: Newton did not converge at t=90.4 (i=50)
# Warning: Newton did not converge at t=90.5 (i=50)
# Warning: Newton did not converge at t=90.60000000000001 (i=50)
# Warning: Newton did not converge at t=90.7 (i=50)
# Warning: Newton did not converge at t=90.80000000000001 (i=50)
# Warning: Newton did not converge at t=90.9 (i=50)
# Warning: Newton did not converge at t=91.0 (i=50)
# Warning: Newton did not converge at t=91.10000000000001 (i=50)
# Warning: Newton did not converge at t=91.2 (i=50)
# Warning: Newton did not converge at t=91.30000000000001 (i=50)
# Warning: Newton did not converge at t=91.4 (i=50)
# Warning: Newton did not converge at t=91.5 (i=50)
# Warning: Newton did not converge at t=91.60000000000001 (i=50)
# Warning: Newton did not converge at t=91.7 (i=50)
# Warning: Newton did not converge at t=91.80000000000001 (i=50)
# Warning: Newton did not converge at t=91.9 (i=50)
# Warning: Newton did not converge at t=92.0 (i=50)
# Warning: Newton did not converge at t=92.10000000000001 (i=50)
# Warning: Newton did not converge at t=92.2 (i=50)
# Warning: Newton did not converge at t=92.30000000000001 (i=50)
# Warning: Newton did not converge at t=92.4 (i=50)
# Warning: Newton did not converge at t=92.5 (i=50)
# Warning: Newton did not converge at t=92.60000000000001 (i=50)
# Warning: Newton did not converge at t=92.7 (i=50)
# Warning: Newton did not converge at t=92.80000000000001 (i=50)
# Warning: Newton did not converge at t=92.9 (i=50)
# Warning: Newton did not converge at t=93.0 (i=50)
# Warning: Newton did not converge at t=93.10000000000001 (i=50)
# Warning: Newton did not converge at t=93.2 (i=50)
# Warning: Newton did not converge at t=93.30000000000001 (i=50)
# Warning: Newton did not converge at t=93.4 (i=50)
# Warning: Newton did not converge at t=93.5 (i=50)
# Warning: Newton did not converge at t=93.60000000000001 (i=50)
# Warning: Newton did not converge at t=93.7 (i=50)
# Warning: Newton did not converge at t=93.80000000000001 (i=50)
# Warning: Newton did not converge at t=93.9 (i=50)
# Warning: Newton did not converge at t=94.0 (i=50)
# Warning: Newton did not converge at t=94.10000000000001 (i=50)
# Warning: Newton did not converge at t=94.2 (i=50)
# Warning: Newton did not converge at t=94.30000000000001 (i=50)
# Warning: Newton did not converge at t=94.4 (i=50)
# Warning: Newton did not converge at t=94.5 (i=50)
# Warning: Newton did not converge at t=94.60000000000001 (i=50)
# Warning: Newton did not converge at t=94.7 (i=50)
# Warning: Newton did not converge at t=94.80000000000001 (i=50)
# Warning: Newton did not converge at t=94.9 (i=50)
# Warning: Newton did not converge at t=95.0 (i=50)
# Warning: Newton did not converge at t=95.10000000000001 (i=50)
# Warning: Newton did not converge at t=95.2 (i=50)
# Warning: Newton did not converge at t=95.30000000000001 (i=50)
# Warning: Newton did not converge at t=95.4 (i=50)
# Warning: Newton did not converge at t=95.5 (i=50)
# Warning: Newton did not converge at t=95.60000000000001 (i=50)
# Warning: Newton did not converge at t=95.7 (i=50)
# Warning: Newton did not converge at t=95.80000000000001 (i=50)
# Warning: Newton did not converge at t=95.9 (i=50)
# Warning: Newton did not converge at t=96.0 (i=50)
# Warning: Newton did not converge at t=96.10000000000001 (i=50)
# Warning: Newton did not converge at t=96.2 (i=50)
# Warning: Newton did not converge at t=96.30000000000001 (i=50)
# Warning: Newton did not converge at t=96.4 (i=50)
# Warning: Newton did not converge at t=96.5 (i=50)
# Warning: Newton did not converge at t=96.60000000000001 (i=50)
# Warning: Newton did not converge at t=96.7 (i=50)
# Warning: Newton did not converge at t=96.80000000000001 (i=50)
# Warning: Newton did not converge at t=96.9 (i=50)
# Warning: Newton did not converge at t=97.0 (i=50)
# Warning: Newton did not converge at t=97.10000000000001 (i=50)
# Warning: Newton did not converge at t=97.2 (i=50)
# Warning: Newton did not converge at t=97.30000000000001 (i=50)
# Warning: Newton did not converge at t=97.4 (i=50)
# Warning: Newton did not converge at t=97.5 (i=50)
# Warning: Newton did not converge at t=97.60000000000001 (i=50)
# Warning: Newton did not converge at t=97.7 (i=50)
# Warning: Newton did not converge at t=97.80000000000001 (i=50)
# Warning: Newton did not converge at t=97.9 (i=50)
# Warning: Newton did not converge at t=98.0 (i=50)
# Warning: Newton did not converge at t=98.10000000000001 (i=50)
# Warning: Newton did not converge at t=98.2 (i=50)
# Warning: Newton did not converge at t=98.30000000000001 (i=50)
# Warning: Newton did not converge at t=98.4 (i=50)
# Warning: Newton did not converge at t=98.5 (i=50)
# Warning: Newton did not converge at t=98.60000000000001 (i=50)
# Warning: Newton did not converge at t=98.7 (i=50)
# Warning: Newton did not converge at t=98.80000000000001 (i=50)
# Warning: Newton did not converge at t=98.9 (i=50)
# Warning: Newton did not converge at t=99.0 (i=50)
# Warning: Newton did not converge at t=99.10000000000001 (i=50)
# Warning: Newton did not converge at t=99.2 (i=50)
# Warning: Newton did not converge at t=99.30000000000001 (i=50)
# Warning: Newton did not converge at t=99.4 (i=50)
# Warning: Newton did not converge at t=99.5 (i=50)
# Warning: Newton did not converge at t=99.60000000000001 (i=50)
# Warning: Newton did not converge at t=99.7 (i=50)
# Warning: Newton did not converge at t=99.80000000000001 (i=50)
# Warning: Newton did not converge at t=99.9 (i=50)

# %% [markdown]
# > **Task 1.5**
# >
# > Compare your solution to the reference solution below. The reference solution is created by running an accurate solver from the Scipy library. You can use it to evaluate your implementation. If you choose a small time step (0.1 days), and your implementation is correct, the solutions should look the same.

# %%
# Compute reference solution using scipy's solve_ivp
t_end = times[-1]
t_dense = np.linspace(0, t_end, 6000)
sol = solve_ivp(
    decay_model_with_sorption,
    t_span=(0, t_end),
    y0=np.array([c0]),
    t_eval=t_dense,
    args=(k, n, alpha),
    max_step=0.8,
    method="BDF",
)

# %%
# Plot the implicit Euler solution against the reference solution
plt.plot(times, c_implicit, label="implicit Euler")
plt.plot(sol.t, sol.y[0], label="scipy solution", linestyle= 'dashed')
plt.legend()
plt.xlabel("time")
plt.ylabel("$C$ [mol/L]")
plt.ylim(bottom=0)
# Out:
# (0.0, 10.492619811342376)

# %% [markdown]
# ## Part 2: Adams-Bashfort method
#
#
# > **Task 2.1**
# >
# > Fill in the code template below to implement a solution of the decay model with the Adams-Bashforth method.

# %%
def solve_adams_bashforth(c0, times, dt, k, n, alpha):
    """
    Solve the decay model with sorption using the Adams-Bashforth method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]

    # Initialize the current state
    c_i = c0

    # Iterate over times
    for i in range(len(times) - 1):
        t_i = times[i]
        
        ### YOUR CODE LINES HERE

    # Convert list of states to a numpy array
    c_array = np.array(c)
    return c_array

# %% [markdown]
# ## Part 3: Numerical stability and accuracy
#
# The code below compares the solution obtained with the implicit Euler scheme to the solution from the explicit Euler scheme and the reference solution.

# %%
def solve_explicit_euler(c0, times, dt, k, n, alpha):
    """
    Solve the decay model with sorption using the explicit Euler method.

    Parameters:
    - c0: initial concentration
    - times: array of time points
    - dt: time increment
    - k: decay rate constant
    - n: exponent for the sorption isotherm
    - alpha: sorption coefficient

    Returns:
    - c_array: array of concentrations at each time point
    """

    # Initialize a list to store the state
    c = [c0]

    # Initialize the current state
    c_prev = c0

    # Iterate over times
    for i in range(1, len(times)):
        t_next = times[i]
        # Explicit Euler update
        c_next = c_prev + dt * decay_model_with_sorption(t_next, c_prev, k, n, alpha)
        c.append(c_next)
        c_prev = c_next

    # Convert list of states to a numpy array
    c_array = np.array(c)
    return c_array

# %% [markdown]
# > **Task 3.1**
# >
# > Run the code cell below that plots the solution obtained with the Adams-Bashforth method to the solution from the implicit and explicit Euler scheme (using the same time step size of $\Delta t = 2 \,\mathrm{d}$). Compare the accuracy of the Adams-Bashforth solution to the one from the Euler schemes.

# %%
dt = 2
t_end = np.maximum(100, dt * 5)
times = np.arange(0, t_end + dt, dt)  # in days
n_times = len(times)

c_adams_bashforth = solve_adams_bashforth(c0, times, dt=dt, k=k, n=n, alpha=alpha)
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
c_explicit = solve_explicit_euler(c0, times, dt, k, n, alpha)
plt.plot(sol.t, sol.y[0], label="reference solution", color="black")
plt.plot(times, c_adams_bashforth, label="Adams-Bashforth")
plt.plot(times, c_implicit, label="Implicit Euler")
plt.plot(times, c_explicit, label="Explicit Euler")
plt.legend()

# %% [markdown]
# > **Task 3.2**
# >
# > Vary the time step in the code cell below, using values of 0.1 day, 5 day, 10 days, 15 days. Compare the behavior of the implicit and explicit Euler scheme and the Adams-Bashforth scheme at the different time step sizes.
# >
# > Take notes about the results – you will need them for the report later on. You may also want to schematically sketch the plots (exact values are not important).

# %%
dt = 0.1
t_end = np.maximum(100, dt * 5)
times = np.arange(0, t_end + dt, dt)  # in days
n_times = len(times)

c_adams_bashforth = solve_adams_bashforth(c0, times, dt=dt, k=k, n=n, alpha=alpha)
c_implicit = solve_implicit_euler(c0, times, dt, k, n, alpha, tolerance, max_iter)
c_explicit = solve_explicit_euler(c0, times, dt, k, n, alpha)
plt.plot(sol.t, sol.y[0], label="reference solution", color="black")
plt.plot(times, c_adams_bashforth, label="Adams-Bashforth")
plt.plot(times, c_implicit, label="Implicit Euler")
plt.plot(times, c_explicit, label="Explicit Euler")
plt.legend()
plt.title(fr"Solution for $\Delta t = {dt} \,\mathrm{{d}}$")

# %% [markdown]
# > By Anna Störiko and Ronald Brinkgreve, Delft University of Technology. CC BY 4.0, more info [on the Credits page of Workbook](https://mude.citg.tudelft.nl/workbook-2026/credits.html).
